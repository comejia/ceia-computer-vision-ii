# %% [markdown]
# # Detección de objetos con YOLOv11

# %% [markdown]
# YOLO (You Only Look Once) es una familia de modelos de detección de objetos en tiempo real. En esta sección, se muestra cómo utilizar un modelo YOLOv11 para detectar objetos en imágenes.

# %%
from ultralytics import YOLO
import cv2

video_path = "./oficina.mp4"

# %%
# Load a pretrained YOLO11 model
model_n = YOLO("yolo11n.pt")
model_s = YOLO("yolo11s.pt")
model_m = YOLO("yolo11m.pt")
model_l = YOLO("yolo11l.pt")

# %%
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video.")
    raise Exception("Could not open video.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video stream.")
        break

    results = model_s.predict(source=frame, device="cpu", conf=0.7, imgsz=1280, verbose=True)
    annotated_frame = results[0].plot()

    cv2.imshow("YOLO Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 736x1280 5 persons, 4 chairs, 2 tvs, 1 keyboard, 263.6ms
# Speed: 7.2ms preprocess, 263.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
# QFontDatabase: Cannot find font directory /home/comejia/projects/ceia/ceia-computer-vision-ii/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/comejia/projects/ceia/ceia-computer-vision-ii/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/comejia/projects/ceia/ceia-computer-vision-ii/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/comejia/projects/ceia/ceia-computer-vision-ii/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/comejia/projects/ceia/ceia-computer-vision-ii/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# 0: 736x1280 5 persons, 4 chairs, 2 tvs, 1 keyboard, 250.6ms
# Speed: 3.6ms preprocess, 250.6ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 cup, 3 chairs, 2 tvs, 1 keyboard, 282.7ms
# Speed: 3.9ms preprocess, 282.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 cup, 3 chairs, 2 tvs, 1 keyboard, 286.8ms
# Speed: 4.8ms preprocess, 286.8ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 cup, 4 chairs, 2 tvs, 1 laptop, 1 keyboard, 259.1ms
# Speed: 4.0ms preprocess, 259.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 cup, 4 chairs, 2 tvs, 1 keyboard, 276.3ms
# Speed: 3.8ms preprocess, 276.3ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 cup, 3 chairs, 1 tv, 1 laptop, 1 keyboard, 258.9ms
# Speed: 4.1ms preprocess, 258.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 cup, 3 chairs, 1 tv, 1 laptop, 203.5ms
# Speed: 4.2ms preprocess, 203.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 5 persons, 1 cup, 4 chairs, 1 tv, 1 laptop, 215.4ms
# Speed: 3.7ms preprocess, 215.4ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 persons, 1 cup, 3 chairs, 1 tv, 1 laptop, 211.1ms
# Speed: 3.0ms preprocess, 211.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 4 persons, 1 cup, 3 chairs, 1 tv, 1 laptop, 219.5ms
# Speed: 3.8ms preprocess, 219.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)

# %% [markdown]
# 📝 Mientras mas grande el modelo usado, mas tardaará en procesar cada imagen, pero también puede detectar objetos con mayor precisión. Para videos pregrabados, el modelo va a procesar todos los frames, pero para videos en vivo puede exister **perdida de frames** si el modelo tarda mucho en procesar cada frame. Por lo tanto, para videos en vivo es recomendable usar un modelo mas pequeño, como el modelo "s" (small), mientras que para videos pregrabados se puede usar un modelo mas grande, como el modelo "m" (medium).
